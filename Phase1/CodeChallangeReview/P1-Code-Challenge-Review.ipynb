# %% [markdown]
# # Phase 1 Code Challenge Review
#
# ![let's do this](https://media.giphy.com/media/12WPxqBJAwOuIM/giphy.gif)

# %% [markdown]
# The topics covered will be:
#
#   - [Interacting with Pandas dataframes](#dataframes)
#   - [Visualization](#viz)
#   - [Python Data Structures](#datastructures)

# %%
# My function to call on y'all
# from src.call import call_on_students

# %% [markdown]
# <a id='dataframes'></a>
# # Part 1: Interacting with Pandas DataFrames

# %% [markdown]
# To practice working with dataframes, we will use some Facebook data taken from the UCI Machine Learning repository.
#
# Refer to this paper if you are interested in learning more. There is also a nice description of the features: http://www.math-evry.cnrs.fr/_media/members/aguilloux/enseignements/m1mint/moro2016.pdf

# %%
# Before anything else - need to import pandas!
import pandas as pd

# %% [markdown]
# ## Task 1: Read in the data

# %%
# Can explore the data folder within your notebook
# !ls
# Out:
# P1-Code-Challenge-Review.ipynb src
# data

# %% [markdown]
# Read 'dataset_Facebook.csv' from the data foldeer into the notebook as a Pandas dataframe.
#
# Note: we'll need to set a different delimiter here - let's read the data in, then explain what that means.

# %%
# call_on_students(1)

# %%
# Your code here
import pandas as pd
dataset_df = pd.read_csv('data/dataset_Facebook.csv', sep=';')
dataset_df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0.0                       2752                             5091
# 1     0.0                      10460                            19057
# 2     0.0                       2413                             4373
# 3     1.0                      50128                            87991
# 4     0.0                       7244                            13594
# ..    ...                        ...                              ...
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# 2                       177                      113
# 3                      2211                      790
# 4                       671                      410
# ..                      ...                      ...
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
# 499                     564                      524
#
#      Lifetime Post Consumptions  \
# 0                           159
# 1                          1674
# 2                           154
# 3                          1119
# 4                           580
# ..                          ...
# 495                         985
# 496                         687
# 497                         795
# 498                         832
# 499                         743
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# 4                                                3200
# ..                                                ...
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
# 499                                              2200
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 3                                                 1386
# 4                                                  396
# ..                                                 ...
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
# 499                                                316
#
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
# 499        0    91.0   28.0                 119
#
# [500 rows x 19 columns]

# %% [markdown]
# ## Task 2: Explore the data

# %% [markdown]
# ### 2a: Look at the first five rows of the dataframe, then the last ten rows

# %%
# call_on_students(1)

# %%
dataset_df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime Post Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime Post reach by people who like your Page  \
# 0                                              1640
# 1                                              6112
# 2                                              1503
# 3                                             32048
# 4                                              3200
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                                119
# 1                                               1108
# 2                                                132
# 3                                               1386
# 4                                                396
#
#    comment    like  share  Total Interactions
# 0        4    79.0   17.0                 100
# 1        5   130.0   29.0                 164
# 2        0    66.0   14.0                  80
# 3       58  1572.0  147.0                1777
# 4       19   325.0   49.0                 393

# %%
dataset_df.tail(10)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 490             85979  Photo         3           1             6         11
# 491             85979  Photo         3           1             6          3
# 492             85979   Link         1           1             5         11
# 493             85093  Photo         3           1             1          2
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 490   0.0                       5280                             8703
# 491   1.0                       6184                            10228
# 492   0.0                      45920                             5808
# 493   0.0                       8412                            13960
# 494   0.0                       5400                             9218
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 490                     951                      911
# 491                     956                      901
# 492                     753                      655
# 493                    1179                     1111
# 494                     810                      756
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
# 499                     564                      524
#
#      Lifetime Post Consumptions  \
# 490                        1237
# 491                        1140
# 492                         763
# 493                        1632
# 494                        1003
# 495                         985
# 496                         687
# 497                         795
# 498                         832
# 499                         743
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 490                                               5757
# 491                                               6085
# 492                                              15766
# 493                                               8632
# 494                                               5654
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 490                                              3300
# 491                                              3502
# 492                                             10720
# 493                                              5348
# 494                                              3230
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
# 499                                              2200
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 490                                                431
# 491                                                437
# 492                                                220
# 493                                                699
# 494                                                422
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
# 499                                                316
#
#      comment   like  share  Total Interactions
# 490        1   79.0   30.0                 110
# 491        1  105.0   46.0                 152
# 492        0  128.0    9.0                 137
# 493       17  185.0   55.0                 257
# 494       10  125.0   41.0                 176
# 495        5   53.0   26.0                  84
# 496        0   53.0   22.0                  75
# 497        4   93.0   18.0                 115
# 498        7   91.0   38.0                 136
# 499        0   91.0   28.0                 119

# %% [markdown]
# ### 2b: Look at the information for each column in the dataframe, then describe what you notice

# %%
# call_on_students(1)

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
#  7   Lifetime Post Total Reach                                            500 non-null    int64
#  8   Lifetime Post Total Impressions                                      500 non-null    int64
#  9   Lifetime Engaged Users                                               500 non-null    int64
#  10  Lifetime Post Consumers                                              500 non-null    int64
#  11  Lifetime Post Consumptions                                           500 non-null    int64
#  12  Lifetime Post Impressions by people who have liked your Page         500 non-null    int64
#  13  Lifetime Post reach by people who like your Page                     500 non-null    int64
#  14  Lifetime People who have liked your Page and engaged with your post  500 non-null    int64
#  15  comment                                                              500 non-null    int64
#  16  like                                                                 499 non-null    float64
#  17  share                                                                496 non-null    float64
#  18  Total Interactions                                                   500 non-null    int64
# dtypes: float64(3), int64(15), object(1)
# memory usage: 74.3+ KB

# %% [markdown]
# What do you notice?
#
# - There are missing values. There are 500 rows with 19 columns.

# %% [markdown]
# ### 2c: Describe the dataframe's numeric columns, then describe what you notice

# %%
# call_on_students(1)

# %%
# Your code here
dataset_df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# std      0.448739                22740.78789                     7.680325e+04
# min      0.000000                  238.00000                     5.700000e+02
# 25%      0.000000                 3315.00000                     5.694750e+03
# 50%      0.000000                 5281.00000                     9.051000e+03
# 75%      1.000000                13168.00000                     2.208550e+04
# max      1.000000               180480.00000                     1.110282e+06
#
#        Lifetime Engaged Users  Lifetime Post Consumers  \
# count              500.000000               500.000000
# mean               920.344000               798.772000
# std                985.016636               882.505013
# min                  9.000000                 9.000000
# 25%                393.750000               332.500000
# 50%                625.500000               551.500000
# 75%               1062.000000               955.500000
# max              11452.000000             11328.000000
#
#        Lifetime Post Consumptions  \
# count                  500.000000
# mean                  1415.130000
# std                   2000.594118
# min                      9.000000
# 25%                    509.250000
# 50%                    851.000000
# 75%                   1463.000000
# max                  19779.000000
#
#        Lifetime Post Impressions by people who have liked your Page  \
# count                                       5.000000e+02
# mean                                        1.676638e+04
# std                                         5.979102e+04
# min                                         5.670000e+02
# 25%                                         3.969750e+03
# 50%                                         6.255500e+03
# 75%                                         1.486050e+04
# max                                         1.107833e+06
#
#        Lifetime Post reach by people who like your Page  \
# count                                        500.000000
# mean                                        6585.488000
# std                                         7682.009405
# min                                          236.000000
# 25%                                         2181.500000
# 50%                                         3417.000000
# 75%                                         7989.000000
# max                                        51456.000000
#
#        Lifetime People who have liked your Page and engaged with your post  \
# count                                         500.000000
# mean                                          609.986000
# std                                           612.725618
# min                                             9.000000
# 25%                                           291.000000
# 50%                                           412.000000
# 75%                                           656.250000
# max                                          4376.000000
#
#          comment         like       share  Total Interactions
# count  500.00000   499.000000  496.000000          500.000000
# mean     7.48200   177.945892   27.266129          212.120000
# std     21.18091   323.398742   42.613292          380.233118
# min      0.00000     0.000000    0.000000            0.000000
# 25%      1.00000    56.500000   10.000000           71.000000
# 50%      3.00000   101.000000   19.000000          123.500000
# 75%      7.00000   187.500000   32.250000          228.500000
# max    372.00000  5172.000000  790.000000         6334.000000

# %% [markdown]
# What do you notice?
#
# - We are working with integers and floats

# %% [markdown]
# ## Task 3: Explore null values

# %% [markdown]
# ### 3a: Count how many null values there are in each column

# %%
# call_on_students(1)

# %%
# Your code here
dataset_df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# Lifetime Post reach by people who like your Page                       0
# Lifetime People who have liked your Page and engaged with your post    0
# comment                                                                0
# like                                                                   1
# share                                                                  4
# Total Interactions                                                     0
# dtype: int64

# %% [markdown]
# ### 3b: What are some of the things we could do to deal with null values?

# %%
# call_on_students(1)

# %% [markdown]
# Answer:
#
# - We can fill those null values by adding the median or mean values if it's continuous data. If the data is categorical it will be better to replace those missing values with the most common values.

# %% [markdown]
# ### 3c: Drop records that have null values in the `share` column

# %%
# call_on_students(1)

# %%
dataset_df.dropna(subset = ['share'])
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0.0                       2752                             5091
# 1     0.0                      10460                            19057
# 2     0.0                       2413                             4373
# 3     1.0                      50128                            87991
# 4     0.0                       7244                            13594
# ..    ...                        ...                              ...
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# 2                       177                      113
# 3                      2211                      790
# 4                       671                      410
# ..                      ...                      ...
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
# 499                     564                      524
#
#      Lifetime Post Consumptions  \
# 0                           159
# 1                          1674
# 2                           154
# 3                          1119
# 4                           580
# ..                          ...
# 495                         985
# 496                         687
# 497                         795
# 498                         832
# 499                         743
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# 4                                                3200
# ..                                                ...
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
# 499                                              2200
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 3                                                 1386
# 4                                                  396
# ..                                                 ...
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
# 499                                                316
#
#      comment    like  share  Total Interactions  likes_per_impression
# 0          4    79.0   17.0                 100              0.015518
# 1          5   130.0   29.0                 164              0.006822
# 2          0    66.0   14.0                  80              0.015093
# 3         58  1572.0  147.0                1777              0.017865
# 4         19   325.0   49.0                 393              0.023908
# ..       ...     ...    ...                 ...                   ...
# 495        5    53.0   26.0                  84              0.007033
# 496        0    53.0   22.0                  75              0.008509
# 497        4    93.0   18.0                 115              0.012888
# 498        7    91.0   38.0                 136              0.012031
# 499        0    91.0   28.0                 119              0.012479
#
# [496 rows x 20 columns]

# %% [markdown]
# ## Task 4: Create a column

# %% [markdown]
# An "impression" counts each time a post is displayed.
#
# Create a new column called `likes_per_impression` which divides the number of likes per post by the number of impressions per post.

# %%
# call_on_students(1)

# %%
# Your code here
dataset_df['likes_per_impression'] = dataset_df['like'] / dataset_df['Lifetime Post Total Impressions']
dataset_df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0.0                       2752                             5091
# 1     0.0                      10460                            19057
# 2     0.0                       2413                             4373
# 3     1.0                      50128                            87991
# 4     0.0                       7244                            13594
# ..    ...                        ...                              ...
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# 2                       177                      113
# 3                      2211                      790
# 4                       671                      410
# ..                      ...                      ...
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
# 499                     564                      524
#
#      Lifetime Post Consumptions  \
# 0                           159
# 1                          1674
# 2                           154
# 3                          1119
# 4                           580
# ..                          ...
# 495                         985
# 496                         687
# 497                         795
# 498                         832
# 499                         743
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# 4                                                3200
# ..                                                ...
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
# 499                                              2200
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 3                                                 1386
# 4                                                  396
# ..                                                 ...
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
# 499                                                316
#
#      comment    like  share  Total Interactions  likes_per_impression
# 0          4    79.0   17.0                 100              0.015518
# 1          5   130.0   29.0                 164              0.006822
# 2          0    66.0   14.0                  80              0.015093
# 3         58  1572.0  147.0                1777              0.017865
# 4         19   325.0   49.0                 393              0.023908
# ..       ...     ...    ...                 ...                   ...
# 495        5    53.0   26.0                  84              0.007033
# 496        0    53.0   22.0                  75              0.008509
# 497        4    93.0   18.0                 115              0.012888
# 498        7    91.0   38.0                 136              0.012031
# 499        0    91.0   28.0                 119              0.012479
#
# [500 rows x 20 columns]

# %% [markdown]
# ## Task 5: Multiply `likes_per_impression` by 100 so they look like percentages

# %% [markdown]
# Make a new column for this, `likes_per_impression_perc`, to capture this output.

# %%
# call_on_students(1)

# %%
# Your code here
dataset_df['likes_per_impression_perc'] = dataset_df['likes_per_impression'] * 100
dataset_df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0.0                       2752                             5091
# 1     0.0                      10460                            19057
# 2     0.0                       2413                             4373
# 3     1.0                      50128                            87991
# 4     0.0                       7244                            13594
# ..    ...                        ...                              ...
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  ...  Lifetime Post Consumptions  \
# 0                       178  ...                         159
# 1                      1457  ...                        1674
# 2                       177  ...                         154
# 3                      2211  ...                        1119
# 4                       671  ...                         580
# ..                      ...  ...                         ...
# 495                     733  ...                         985
# 496                     537  ...                         687
# 497                     625  ...                         795
# 498                     626  ...                         832
# 499                     564  ...                         743
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# 4                                                3200
# ..                                                ...
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
# 499                                              2200
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 3                                                 1386
# 4                                                  396
# ..                                                 ...
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
# 499                                                316
#
#      comment    like  share  Total Interactions  likes_per_impression  \
# 0          4    79.0   17.0                 100              0.015518
# 1          5   130.0   29.0                 164              0.006822
# 2          0    66.0   14.0                  80              0.015093
# 3         58  1572.0  147.0                1777              0.017865
# 4         19   325.0   49.0                 393              0.023908
# ..       ...     ...    ...                 ...                   ...
# 495        5    53.0   26.0                  84              0.007033
# 496        0    53.0   22.0                  75              0.008509
# 497        4    93.0   18.0                 115              0.012888
# 498        7    91.0   38.0                 136              0.012031
# 499        0    91.0   28.0                 119              0.012479
#
#      likes_per_impression_perc
# 0                     1.551758
# 1                     0.682164
# 2                     1.509261
# 3                     1.786546
# 4                     2.390761
# ..                         ...
# 495                   0.703291
# 496                   0.850859
# 497                   1.288803
# 498                   1.203067
# 499                   1.247943
#
# [500 rows x 21 columns]

# %% [markdown]
# ## Task 6: How many examples of each type of post?

# %% [markdown]
# I'm seeing a lot of posts with the type of 'Photo' - are there other post types, and what's the breakdown?

# %%
# call_on_students(1)

# %%
# Your code here
dataset_df['Type'].value_counts()
# Out:
# Type
# Photo     426
# Status     45
# Link       22
# Video       7
# Name: count, dtype: int64

# %%
# Can also look at the percentages
dataset_df['Type'].value_counts(normalize = True)
# Out:
# Type
# Photo     0.852
# Status    0.090
# Link      0.044
# Video     0.014
# Name: proportion, dtype: float64

# %% [markdown]
# ## Task 7: Find the five Photos with the highest likes/impression ratio

# %% [markdown]
# Find the five **Photos** with the highest number in our new `likes_per_impression_perc` column

# %%
# call_on_students(1)

# %%
# Your code here
dataset_df.loc[dataset_df['Type'] == 'Photo'].sort_values(by = 'likes_per_impression_perc', ascending = False).head(5)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 476             86909  Photo         1           1             6         10
# 87             137177  Photo         3          11             3         10
# 161            135617  Photo         2           9             7          3
# 81             137177  Photo         3          11             6         10
# 92             137059  Photo         3          11             1          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 476   1.0                      37088                            10966
# 87    0.0                       4012                             7955
# 161   0.0                       3992                             7255
# 81    0.0                       5990                            11123
# 92    0.0                       4732                             9303
#
#      Lifetime Engaged Users  ...  Lifetime Post Consumptions  \
# 476                    2728  ...                        3183
# 87                      550  ...                         477
# 161                     598  ...                         688
# 81                      657  ...                         512
# 92                      607  ...                         518
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 476                                              66311
# 87                                                4625
# 161                                               4428
# 81                                                5057
# 92                                                6201
#
#      Lifetime Post reach by people who like your Page  \
# 476                                             34352
# 87                                               2218
# 161                                              2420
# 81                                               2628
# 92                                               3136
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 476                                               2021
# 87                                                 403
# 161                                                435
# 81                                                 428
# 92                                                 445
#
#      comment   like  share  Total Interactions  likes_per_impression  \
# 476        7  579.0   47.0                 633              0.052800
# 87         3  270.0   38.0                 311              0.033941
# 161        6  244.0   32.0                 282              0.033632
# 81        18  370.0   53.0                 441              0.033264
# 92         9  301.0   32.0                 342              0.032355
#
#      likes_per_impression_perc
# 476                   5.279956
# 87                    3.394092
# 161                   3.363198
# 81                    3.326441
# 92                    3.235515
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Task 8: Find the most liked Photo

# %% [markdown]
# Locate the **Photo** that has the largest amount of likes in the `like` column

# %%
# call_on_students(1)

# %%
# Your code here
dataset_df['like'].max()
# Out:
# 5172.0

# %%
photo = dataset_df.loc[dataset_df['Type'] == 'Photo']
photo.loc[photo['like'] == photo['like'].max()]
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
#
#      Lifetime Engaged Users  ...  Lifetime Post Consumptions  \
# 244                    8072  ...                        6242
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 244                                             108752
#
#      Lifetime Post reach by people who like your Page  \
# 244                                             51456
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 244                                               3316
#
#      comment    like  share  Total Interactions  likes_per_impression  \
# 244      372  5172.0  790.0                6334              0.016206
#
#      likes_per_impression_perc
# 244                   1.620641
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Task 9: Find the average
#
# What is the mean number of Total Interactions for **Photos**?

# %%
# call_on_students(1)

# %%
# Your code here
dataset_df['Type'] == 'Photo']['Total Interactions'].mean()
# Out:
#   Cell In[169], line 2
#     dataset_df['Type'] == 'Photo']['Total Interactions'].mean()
#                                  ^
# SyntaxError: unmatched ']'

# %% [markdown]
# <a id='viz'></a>
# # Part 2: Visualization

# %%
# Need more imports!
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 10: Bar Chart
#
# Create a bar chart showing the number of posts per month.
#
# Order the x-axis by month as they appear on the calendar.
#
# Don't forget to add labels and a title.
#
# Use the `plt.subplot` method if you can, but if you can't, resort to the `plt` syntax.

# %%
# call_on_students(1)

# %%
# Your code here
# First need to access the number of posts per 
bar_df = dataset_df['Post Month'].value_counts().sort_index()

fig, ax = plt.subplots()
ax.set_xlabel('month')
ax.set_ylabel('number of posts')
ax.bar(x = bar_dataset_df.index, height= bar_dataset_df.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[173], line 8
#       6 ax.set_xlabel('month')
#       7 ax.set_ylabel('number of posts')
# ----> 8 ax.bar(x = bar_dataset_df.index, height= bar_dataset_df.values)
#
# NameError: name 'bar_dataset_df' is not defined

# %%
# Your code here
# Now need to visualize

# %% [markdown]
# Let's discuss: what do you notice?
#
# -

# %% [markdown]
# ## Task 11: Scatter Plot
#
# Create a scatter plot that shows the correlation between total interactions and likes.

# %%
# call_on_students(1)

# %%
# Your code here
sns.scatterplaot(x= dataset_df['like'], y =data_df['Total Interactions'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[175], line 2
#       1 # Your code here
# ----> 2 sns.scatterplaot(x= dataset_df['like'], y =data_df['Total Interactions'])
#
# AttributeError: module 'seaborn' has no attribute 'scatterplaot'

# %% [markdown]
# Let's discuss: what do you notice?
#
# -

# %% [markdown]
# <a id='datastructures'></a>
# # Part 3: Data Structures

# %% [markdown]
# For this next section, we will explore a nested dictionary that comes from the Spotify API.  You won't need to do these kinds of imports and opens on the code challenge, so I'll go ahead and share the code to get started here.
#
# The `data` variable below contains 6 separate pings, each of which returns a list of the top 20 songs streamed on a given day.

# %%
# First we need some imports
import json
import pickle

# %%
# Let's open the pickled file
with open('data/offset_newreleases.p','rb') as read_file:
    responses = pickle.load(read_file)

# %%
data = [json.loads(r) for r in responses]

# %%
# Sanity check - we said there would be 6 pings, are there?
len(data)
# Out:
# 6

# %% [markdown]
# We will work only with the first response.

# %%
first_response = data[0]

# %%
first_response['albums'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# ## Task 12: Navigate the dictionary

# %% [markdown]
# Explore the `first_response` dictionary and find how to access the items list, which contains the details about the twenty songs. Assign the list to the variable `first_twenty_songs`.
#
# Hint: print out the keys at each level with .keys().

# %%
# call_on_students(1)

# %%
# Your code here
first_twenty_songs = []

for x in first_response['albums']['items']:
    first_twenty_songs.append(x)

# %% [markdown]
# ## Task 13: Loop to List

# %% [markdown]
# Create a list of **track names** of all twenty songs using a for loop or list comprehension.

# %%
# call_on_students(1)

# %%
# Your code here

# %% [markdown]
# ## Task 14: Create a new dictionary

# %% [markdown]
# Create a dictionary called `song_dictionary` which consists of each track name `string` as a key and a `tuple` of artists associated with each track as a value.

# %%
# call_on_students(1)

# %%
# Your code here:

# %% [markdown]
# ## Task 15: Write a function

# %% [markdown]
# Create a function with takes an **artist name** and the **song_dictionary** as arguments, and returns a `list` of songs written by that artist.

# %%
# call_on_students(1)

# %%
# Easier to do things outside of a function first
# Let's try for The Weeknd

# %%
# Your code here

def find_song_by_artist(artist_name, song_dict):
    
    '''
    Parameters:
    arist_name: a string of an artist's name to be used to search the dictionary
    song_dict:  a dictionary of top_twenty songs with song name as keys and a list of 
    artist names as values
    
    Returns:
    A list of songs which the given artist appeared on
    '''
    
    pass

# %%
# Test the function:
find_song_by_artist('Selena Gomez', song_dictionary)
